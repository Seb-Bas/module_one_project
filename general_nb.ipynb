# %% [markdown]
# Welcome to the clean Jupyter Notebook

# %%
import custom_functions as cf
merged_data, genres_df, directors_by_profit_oscars, nominations, tmdb_cleaned, genres_names, actors = cf.call_my_pickles()

# %%
cf.plot_profit_by_genre(genres_df)

# %%
cf.plot_oscar_nominations_by_genre(genres_df)

# %%
cf.plot_profit_by_genre(genres_df)

# %%
cf.plot_oscar_dramaadventure_directors(directors_by_profit_oscars)

# %%
cf.plot_actors(actors)
